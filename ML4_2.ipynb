# %% [markdown]
# <a href="https://colab.research.google.com/github/Niraj2003/MachineLearning/blob/main/ML4_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
import seaborn as sns
data = sns.load_dataset('iris')
data.head()
sns.countplot(x = 'species', data=data)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
X = data.iloc[:,:4].values
y = data['species'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler() #subtracting the mean of each feature and then dividing by its standard deviation
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.svm import SVC
svmclassifier = SVC(kernel = 'linear', random_state = 0)
svmclassifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
y_pred = svmclassifier.predict(X_test)
print(y_pred)
# Out:
# ['virginica' 'virginica' 'virginica' 'versicolor' 'versicolor' 'setosa'
#  'setosa' 'setosa' 'versicolor' 'versicolor' 'setosa' 'virginica'
#  'virginica' 'virginica' 'virginica' 'virginica' 'setosa' 'setosa'
#  'virginica' 'virginica' 'setosa' 'versicolor' 'versicolor' 'setosa'
#  'setosa' 'versicolor' 'versicolor' 'versicolor' 'versicolor' 'virginica']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 9  0  0]
#  [ 0 10  2]
#  [ 0  0  9]]

# %%
# pip install scikit-plot

# %%
from scikitplot.metrics import plot_confusion_matrix
plot_confusion_matrix(y_test, y_pred, normalize=True)
plt.show()

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, svmclassifier.predict(X_test)) * 100
accuracy
# Out:
# 93.33333333333333
